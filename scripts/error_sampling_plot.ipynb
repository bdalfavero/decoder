# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/error_counts.csv", index_col="p")

# %%
fig, ax = plt.subplots()
df.plot.bar(ax=ax, stacked=True)
# Out:
# <Axes: xlabel='p'>
